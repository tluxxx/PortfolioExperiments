# %% [markdown]
# <a href="https://colab.research.google.com/github/tluxxx/PortfolioExperiments/blob/main/ImportNonStockDataTest01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Non Stock Data

# %%
# !pip install quandl
# !pip install ecbdata

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import quandl
import yfinance as yf
from ecbdata import ecbdata
import datetime as dt

# %%
# motivation for the study

# import currency data from yfinance
start_date, end_date = '1900-01-01', '2024-07-31'
eurusd_yf = yf.download('EURUSD=X', start=start_date, end=end_date)

# printing results and plotting
print('')
print(f'yfinance first date EUR:  {eurusd_yf.index[0]}')
print('')
plt.plot(eurusd_yf['Adj Close'])
plt.legend(['yfinance'], loc='upper right')
plt.title(' EUR - USD exchange rate')
plt.xlabel('time')
plt.ylabel('exchange rate')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# yfinance first date EUR:  2003-12-01 00:00:00

# %% [markdown]
# #1. Import Currency Data

# %%
import pandas_datareader as pdr

# setting the parameters
start_date, end_date = '1900-01-01', '2024-07-31'

# import currency data from FRED
jpyusd = pdr.get_data_fred('DEXJPUS', start_date, end_date)
gbpusd = pdr.get_data_fred('DEXUSUK', start_date, end_date)
eurusd = pdr.get_data_fred('DEXUSEU', start_date, end_date)

# import currency data from yfinance
eurusd_yf = yf.download('EURUSD=X', start=start_date, end=end_date)

# printing first occurence of data in database
print('\n' * 2)
print(f'FRED first date JPY-USD:      {jpyusd.index[0]}')
print(f'FRED first date GBP-USD:      {gbpusd.index[0]}')
print(f'FRED first date EUR-USD:      {eurusd.index[0]}')
print(f'yfinance first date EUR-USD:  {eurusd_yf.index[0]}')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# FRED first date JPY-USD:      1971-01-04 00:00:00
# FRED first date GBP-USD:      1971-01-04 00:00:00
# FRED first date EUR-USD:      1999-01-04 00:00:00
# yfinance first date EUR-USD:  2003-12-01 00:00:00

# %%
# plotting overlay of yfincne and FRED data

plt.plot(eurusd)
plt.plot(eurusd_yf['Adj Close'])
plt.legend(['FRED','yfinance'], loc='upper right')
plt.title(' EUR - USD exchange rate')
plt.xlabel('time')
plt.ylabel('exchange rate')
plt.show()

# %% [markdown]
# # 2. Import of T-Bills, T-Notes and T-Bonds Data

# %%
# treasury instruments
start_date, end_date = '1900-01-01', '2024-06-30'

# treasury bills
tbill_3m = pdr.get_data_fred('DTB3', start_date, end_date)   # 3-Month Treasury Bill Secondary Market Rate, Discount Basis
tbill_6m = pdr.get_data_fred('DTB6', start_date, end_date)   # 6-Month Treasury Bill Secondary Market Rate, Discount Basis
tbill_1y = pdr.get_data_fred('DTB1YR',start_date, end_date)  # 1-Year Treasury Bill Secondary Market Rate, Discount Basis
tbill_1y1 = pdr.get_data_fred('DGS1', start_date, end_date)  # Market Yield on U.S. Treasury Securities at 1-Year Constant Maturity, Quoted on an Investment Basis

# treasury notes
tnote_2y = pdr.get_data_fred('DGS2', start_date, end_date)   # Market Yield on U.S. Treasury Securities at 2-Year Constant Maturity, Quoted on an Investment Basis
tnote_5y = pdr.get_data_fred('DGS5', start_date, end_date)   # Market Yield on U.S. Treasury Securities at 5-Year Constant Maturity, Quoted on an Investment Basis
tnote_10y = pdr.get_data_fred('DGS10', start_date, end_date) # Market Yield on U.S. Treasury Securities at 10-Year Constant Maturity, Quoted on an Investment Basis

# treasury bonds
tbond_20y = pdr.get_data_fred('DGS20', start_date, end_date) # Market Yield on U.S. Treasury Securities at 20-Year Constant Maturity, Quoted on an Investment Basis
tbond_30y = pdr.get_data_fred('DGS30', start_date, end_date) # Market Yield on U.S. Treasury Securities at 30-Year Constant Maturity, Quoted on an Investment Basis

# printing first data in database
print('\n' * 2)
print(f'FRED first date DTB3:      {tbill_3m.index[0]}')
print(f'FRED first date DTB6:      {tbill_6m.index[0]}')
print(f'FRED first date DTB1YR:    {tbill_1y.index[0]}')
print(f'FRED first date DGS1:      {tbill_1y1.index[0]}')
print(f'FRED first date DGS2:      {tnote_2y.index[0]}')
print(f'FRED first date DGS5:      {tnote_5y.index[0]}')
print(f'FRED first date DGS10:     {tnote_10y.index[0]}')
print(f'FRED first date DGS20:     {tbond_20y.index[0]}')
print(f'FRED first date DGS30:     {tbond_30y.index[0]}')
# Out:
# FRED first date DTB3:      1954-01-04 00:00:00
# FRED first date DTB6:      1958-12-09 00:00:00
# FRED first date DTB1YR:    1959-07-15 00:00:00
# FRED first date DGS1:      1962-01-02 00:00:00
# FRED first date DGS2:      1976-06-01 00:00:00
# FRED first date DGS5:      1962-01-02 00:00:00
# FRED first date DGS10:     1962-01-02 00:00:00
# FRED first date DGS20:     1962-01-02 00:00:00
# FRED first date DGS30:     1977-02-15 00:00:00

# %%
plt.plot(tbill_1y)
plt.plot(tbill_1y1)
plt.legend(['1y Secondary Market','1y Constant Maturity'], loc='upper right')
plt.show()

# %%
plt.plot(tnote_2y)
plt.plot(tnote_5y)
plt.plot(tnote_10y)
plt.legend(['2y note', '5y_note','10y_note'], loc='upper right')
plt.show()

# %%
plt.plot(tbond_20y)
plt.plot(tbond_30y)
plt.legend(['20y_bond','30y_bond'], loc='upper right')
plt.show()

# %% [markdown]
# # 3. Import of Commodity data

# %%
# Gold-data
start_date, end_date = '1900-01-01', '2024-07-30'

# from yfinance
gold_yf = 'GC=F'
gold_1 = yf.download(gold_yf, start=start_date, end=end_date)

# from NASDAQ via quandl
gold_na = 'LBMA/GOLD'
gold_2 = quandl.get(gold_na, start_date=start_date, end_date=end_date)   # obviously discontinued end 2023

# plot & print
print('\n' * 2)
print(f'first data yfinance: {gold_1.index[0]},   first data NASDAQ: {gold_2.index[0]}')
print(f'last data yfinance:  {gold_1.index[-1]},   last data NASDAQ:  {gold_2.index[-1]}')
print('\n')

plt.plot(gold_1['Adj Close'])
plt.plot(gold_2['USD (AM)'])
plt.legend(['yfinance','Quandl'], loc='upper left')
plt.title(' Gold in USD ')
plt.xlabel('time')
plt.ylabel('price (USD)')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# first data yfinance: 2000-08-30 00:00:00,   first data NASDAQ: 1968-01-02 00:00:00
# last data yfinance:  2024-07-29 00:00:00,   last data NASDAQ:  2023-12-28 00:00:00

# %%
# crude oil data
start_date, end_date = '1900-01-01' , '2024-07-31'

# from FRED
wti_prices =  pdr.get_data_fred('DCOILWTICO', start=start_date, end=end_date)
brent_prices = pdr.get_data_fred('DCOILBRENTEU', start=start_date, end=end_date)

# from yfinance
wti_yf = 'CL=F'
brent_yf = 'BZ=F'
wti_prices_yf = yf.download(wti_yf, start=start_date, end=end_date)
brent_prices_yf = yf.download(brent_yf, start=start_date, end=end_date)

# plot and print
print('\n' * 2)
print(f'FRED:       first data WTI: {wti_prices.index[0]},   first data Brent: {brent_prices.index[0]}')
print(f'FRED:       last data WTI:  {wti_prices.index[-1]},   last data Brent:  {brent_prices.index[-1]}')
print(f'yfinance:   first data WTI: {wti_prices_yf.index[0]}    first data Brent:{brent_prices_yf.index[0]}')
print(f'yfinance:   last data WTI:  {wti_prices_yf.index[-1]},   last data Brent: {brent_prices_yf.index[-1]}')
print('\n')

plt.plot(wti_prices)
plt.plot(wti_prices_yf.Close)
plt.legend(['FRED-WTI','yfinance Crude Oil'], loc='upper left')#
plt.title('Crude Oil Prices')
plt.xlabel('time')
plt.ylabel('price (USD/barrel)')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# FRED:       first data WTI: 1986-01-02 00:00:00,   first data Brent: 1987-05-20 00:00:00
# FRED:       last data WTI:  2024-07-29 00:00:00,   last data Brent:  2024-07-29 00:00:00
# yfinance:   first data WTI: 2000-08-23 00:00:00    first data Brent:2007-07-30 00:00:00
# yfinance:   last data WTI:  2024-07-30 00:00:00,   last data Brent: 2024-07-30 00:00:00

# %%
plt.plot(wti_prices)
plt.plot(wti_prices_yf.Close)

plt.legend(['FRED-WTI','yfinance Crude Oil'], loc='upper left')#
plt.title('Crude Oil Prices')
plt.xlabel('time')
plt.ylabel('price (USD/barrel)')
plt.show()

# %% [markdown]
# # 4. Inflation and other macroeconomic data US

# %%
# changes of Consumer Price Index US

start_date, end_date = '1900-01-01' , '2024-07-31'
infl_1 =  pdr.get_data_fred('FPCPITOTLZGUSA', start=start_date, end=end_date)
cpi_2 = pdr.get_data_fred('CPIAUCNS', start=start_date, end=end_date)           # CPI:Consumer Price Index for All Urban Consumers: All Items in U.S. City Average (CPIAUCNS)
infl_2 = (cpi_2 - cpi_2.shift(12))/cpi_2.shift(12) *100

# print and plot
print('\n' * 2)
print(f'FRED, FPCPITOTLZGUSA: first date inflation-rate: {infl_1.index[0]}   last date inflation-rate: {infl_1.index[-1]}')
print(f'FRED, CPIAUCNS:       first date inflation-rate: {infl_2.index[0]}   last date inflation-rate: {infl_2.index[-1]}')
print('\n')

plt.plot(infl_1)
plt.plot(infl_2)
plt.legend(['inflation rates (as per database)','inflation rates (calculated from CPI)'], loc='upper right')
plt.title('Inflation rates (US)')
plt.xlabel('time')
plt.ylabel('price index rate of change')
plt.show()
# Out:
# FRED, FPCPITOTLZGUSA: first date inflation-rate: 1960-01-01 00:00:00   last date inflation-rate: 2023-01-01 00:00:00
# FRED, CPIAUCNS:       first date inflation-rate: 1913-01-01 00:00:00   last date inflation-rate: 2024-06-01 00:00:00

# %% [markdown]
# # 5.Inflation and other macroeconomic data EURO -Zone

# %%
# Inflation Data Euro-zone
start_date, end_date = '1997-01-01' , '2024-07-31'

# download data
data_key = 'ICP.M.U2.N.000000.4.ANR'  # HICP - Overall index, Euro area (changing composition), Monthly
inflation_eu = ecbdata.get_series(data_key, start=start_date, end=end_date)
inflation_eu.TIME_PERIOD = pd.to_datetime(inflation_eu.TIME_PERIOD)
inflation_eu = inflation_eu.set_index('TIME_PERIOD')
inflation_eu = inflation_eu.OBS_VALUE.astype(float)

# %%
# inflation data, retrieved from ECB database
main_title = 'Inflation rate EU'
sub_title = f'from   {start_date}   to   {end_date} '
title = main_title + '<br><br><sup>' + sub_title + '</sup>'

fig = go.Figure()
fig.add_trace(go.Scatter(x=inflation_eu.index, y=inflation_eu, name='EU inflation data from ecbdata'))
fig.update_layout(template='plotly_dark', autosize=False, width=1000, height=600)
fig.update_layout(title=title, xaxis_title='time', yaxis_title='inflation rate (%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ECB key interest Rate
start_date, end_date = '1900-01-01' , '2024-07-31'

# download data
data_key = 'FM.D.U2.EUR.4F.KR.MRR_RT.LEV'     # Main refinancing operations - Minimum bid rate/fixed rate (date of changes) - Level, Euro area (changing composition), Daily
ecb_int = ecbdata.get_series(data_key, start=start_date, end=end_date)
ecb_int.TIME_PERIOD = pd.to_datetime(ecb_int.TIME_PERIOD)
ecb_int = ecb_int.set_index('TIME_PERIOD')
ecb_int = ecb_int.OBS_VALUE.astype(float)

# %%
# key interest rate data, retrieved from ECB database
main_title = 'ECB key interest rate EU '
sub_title = f'from   {start_date}   to   {end_date} '
title = main_title + '<br><br><sup>' + sub_title + '</sup>'

fig = go.Figure()
fig.add_trace(go.Scatter(x=ecb_int.index, y=ecb_int, line_shape='hv', name='ECB main financing facility (download from ecbdata)'))
fig.update_layout(template='plotly_dark', autosize=False, width=1200, height=600)
fig.update_layout(title=title, xaxis_title='time', yaxis_title='interest rate (%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 6. Integration of Country specific data for pre-EURO periods

# %%
start_period, end_period = '1992-01-01', '2024-07-31'

# %%
# data from German Statistical Office (1991-1998)
data_ger = pd.read_excel('/content/gdrive/My Drive/ColabNotebooks/VariousTopics/PortfolioTests/data/GermanInflationData(1991-2024).xlsx', sheet_name='DATA')
inflation_ger = pd.Series(data_ger['chg_12m'].tolist(), index=data_ger['date'])

inflation_ger = inflation_ger.loc[start_period:]
inflation_ger.loc[start_period] = np.nan

# combining GER and ECB data
cut_off_date ='1998-01-31'
df1 = inflation_ger.loc[start_period:cut_off_date]
df2 = inflation_eu.loc[cut_off_date:]
inflation = pd.concat([df1,df2])
inflation.name = 'inflation'

# %%
# visualisation of the constituents of the inflation data
main_title = 'Inflation rates Germany and EU '
sub_title = f'from   {start_period}   to   {end_period} '
title = main_title + '<br><br><sup>' + sub_title + '</sup>'

fig = go.Figure()
fig.add_trace(go.Scatter(x=inflation_ger.index, y=inflation_ger, name='Inflation Germany (German Statistical Office)'))
fig.add_trace(go.Scatter(x=inflation_eu.index, y=inflation_eu.OBS_VALUE, name='Inflation EU (Euro-Stat)'))
fig.update_layout(template='plotly_dark', autosize=False, width=1000, height=600)
fig.update_layout(title=title, xaxis_title='time', yaxis_title='inflation rate (%)', legend_title='Sources')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# aggregated inflation rates calculated from different sources
main_title = 'aggregated inflation rates Germany/EU '
sub_title = f'Germany from {start_period} to {cut_off_date},  EU from {cut_off_date} to {end_period} '
title = main_title + '<br><br><sup>' + sub_title + '</sup>'

fig = go.Figure()
fig.add_trace(go.Scatter(x=inflation.index, y=inflation, name='Inflation Germany & EU'))
fig.update_layout(template='plotly_dark', autosize=False, width=1000, height=600)
fig.update_layout(title=title, xaxis_title='time', yaxis_title='inflation-rate(%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# German Bundesbank discount rates for every day (approximation, all values as of 01-of each month)
data_db = pd.read_excel('/content/gdrive/My Drive/ColabNotebooks/VariousTopics/PortfolioTests/data/DiscountRatesGermanBundesbank (1990-1998).xlsx',sheet_name='DATA' )
data_db['date'] = pd.to_datetime(data_db['date'])

# generation of data frame with relevant data
## monthly data
end_date_int = '1998-12-31'
disc_x = (data_db[data_db['date'] >= start_period]['interest']).tolist()
disc_r = pd.DataFrame({'date':data_db[data_db['date'] >= start_period]['date'].tolist(),
                       'interest':disc_x})
## conversion to daily data (approximation: if interest rate changes during a month, the change will be implemented at first day of following month
dates = pd.date_range(start_period, end_date_int)
values = np.nan * len(dates)
dates_d = pd.DataFrame({'date': dates,
                        'interest': values})
xx = pd.merge(dates_d, disc_r, how='left', on='date')['interest_y']
xx.ffill(inplace=True)
db_int = pd.DataFrame({'interest':xx.tolist()},
                      index = dates)

# aggregation of German Discount rate with ECB key interest rate

df2 =pd.DataFrame({'interest':ecb_int.tolist()}, index=ecb_int.index)
x = pd.concat([db_int, df2])

interest = pd.concat([db_int, x])
interest = interest['interest'].astype(float)
int_agg = interest[~interest.index.duplicated(keep='first')]

# %%
# visualisation of the constituents of the intrest rate
main_title = 'Central Bank interest rates Germany and EU '
sub_title = f'from   {start_period}   to   {end_period} '
title = main_title + '<br><br><sup>' + sub_title + '</sup>'

fig = go.Figure()
fig.add_trace(go.Scatter(x=db_int.index, y=db_int['interest'], name='Discount Rate German Bundesbank (until 1998-12)'))
fig.add_trace(go.Scatter(x=ecb_int.index, y=ecb_int, name='ECB main financing facility (from 1999-01)'))
fig.update_layout(template='plotly_dark', autosize=False, width=1200, height=600)
fig.update_layout(title=title, xaxis_title='time', yaxis_title='interest rate (%)', legend_title='Sources')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
main_title = 'aggregated interest-rates '
sub_title = f'Bundesbank from {start_period} to {end_date_int},  ECB from {end_date_int} to {end_period} '
title = main_title + '<br><br><sup>' + sub_title + '</sup>'

fig = go.Figure()
fig.add_trace(go.Scatter(x=int_agg.index, y=int_agg, name='aggregated interest rates'))
fig.update_layout(template='plotly_dark', autosize=False, width=1000, height=600)
fig.update_layout(title=title, xaxis_title='time', yaxis_title='intrest-rate (%)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
